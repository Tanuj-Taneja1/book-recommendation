# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data=pd.read_csv("books.csv",error_bad_lines=False,index_col="bookID")
data.head()
# Out:
# C:\Users\nipun\AppData\Local\Temp\ipykernel_88160\2759877276.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data=pd.read_csv("books.csv",error_bad_lines=False,index_col="bookID")
# Skipping line 3350: expected 12 fields, saw 13
# Skipping line 4704: expected 12 fields, saw 13
# Skipping line 5879: expected 12 fields, saw 13
# Skipping line 8981: expected 12 fields, saw 13
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                            authors  \
# bookID
# 1       J.K. Rowling/Mary GrandPré
# 2       J.K. Rowling/Mary GrandPré
# ...

# %%
data.shape
# Out:
# (11123, 11)

# %%
data.columns
# Out:
# Index(['title', 'authors', 'average_rating',
#        'isbn', 'isbn13', 'language_code',
#        '  num_pages', 'ratings_count',
#        'text_reviews_count', 'publication_date',
#        'publisher'],
#       dtype='object')

# %%
data.drop(['isbn', 'isbn13'], axis=1 ,inplace=True)
data.head()
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                            authors  \
# bookID
# 1       J.K. Rowling/Mary GrandPré
# 2       J.K. Rowling/Mary GrandPré
# 4                     J.K. Rowling
# 5       J.K. Rowling/Mary GrandPré
# 8       J.K. Rowling/Mary GrandPré
#
#         average_rating language_code  \
# bookID
# 1                 4.57           eng
# 2                 4.49           eng
# 4                 4.42           eng
# 5                 4.56           eng
# 8                 4.78           eng
#
#           num_pages  ratings_count  \
# bookID
# 1               652        2095690
# 2               870        2153167
# ...

# %%
data.dtypes
# Out:
# title                  object
# authors                object
# average_rating        float64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %%
data.describe()
# Out:
#        average_rating     num_pages  \
# count    11123.000000  11123.000000
# mean         3.934075    336.405556
# std          0.350485    241.152626
# min          0.000000      0.000000
# 25%          3.770000    192.000000
# 50%          3.960000    299.000000
# 75%          4.140000    416.000000
# max          5.000000   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %%
data.isnull().any()
# Out:
# title                 False
# authors               False
# average_rating        False
# language_code         False
#   num_pages           False
# ratings_count         False
# text_reviews_count    False
# publication_date      False
# publisher             False
# dtype: bool

# %%
data.describe(include="object")
# Out:
#             title       authors language_code  \
# count       11123         11123         11123
# unique      10348          6639            27
# top     The Iliad  Stephen King           eng
# freq            9            40          8908
#
#        publication_date publisher
# count             11123     11123
# unique             3679      2290
# top           10/1/2005   Vintage
# freq                 56       318
